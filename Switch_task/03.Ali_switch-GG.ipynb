# %%
import pandas as pd
import numpy as np
import datetime
import time
import pickle
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline
from collections import Counter
from random import choices, sample
from gensim.models import Word2Vec
import gc
pd.set_option('display.float_format',lambda x : '%.2f' % x)
from math import log10
from collections import Counter

# %%
PART = '1'

# %%
with open('../Taobao_v3/dict_knn_table/knn_table_'+ PART +'.pkl', 'rb') as file:
    knn_table = pickle.load(file)

# %%
with open('./freq_dict.pkl', 'rb') as file:
    target_log_dict, next_log_dict = pickle.load(file)

# %%
model_w2v = Word2Vec.load("../Taobao_v3/iid_1days.model")

# %%
def get_embedding(target_iid, next_iid):
    if target_iid in target_log_dict:
        tar_freq = target_log_dict[int(target_iid)]
    else:
        tar_freq = 0
    if next_iid in next_log_dict:
        next_freq = next_log_dict[int(next_iid)]
    else:
        next_freq = 0
    freq = np.append([tar_freq], [next_freq])
    emb_pair = np.append(model_w2v.wv[target_iid], model_w2v.wv[next_iid])
    embedding = np.append(freq, emb_pair)
    return embedding

# %%
from keras import models
model = models.load_model('./saved_model/Ali_switch_0602_G.h5')
# Out:
# Using TensorFlow backend.

# %%
pred_dict = {}

# %%
for target_iid in tqdm(list(knn_table.keys())):
    topn, cos = zip(*knn_table[target_iid])
    pred_list = []
    for next_iid in topn:
        pred_list.append(np.argmax(model.predict(get_embedding(target_iid, next_iid).reshape(1, -1))[0]))
    pred_dict[int(target_iid)] = Counter(pred_list).most_common()[0][0]
# Out:
#  32%|███▏      | 120207/381185 [1:35:11<3:30:21, 20.68it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  38%|███▊      | 143848/381185 [1:54:20<3:12:52, 20.51it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  43%|████▎     | 165781/381185 [2:12:08<2:54:22, 20.59it/s] IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  50%|████▉     | 189353/381185 [2:31:13<2:36:32, 20.42it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  56%|█████▌    | 212801/381185 [2:50:14<2:17:00, 20.48it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  62%|██████▏   | 234854/381185 [3:08:07<1:58:06, 20.65it/s]IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
#  94%|█████████▍| 357428/381185 [4:47:41<19:15, 20.55it/s]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
with open('../pred_dict/pred_dict_' + PART + '.pkl', 'wb') as file:
    pickle.dump(pred_dict, file)

# %%
len(pred_dict)
# Out:
# 381185

# %%
knn_table.keys()
# Out:
# dict_keys(['3', '4', '9', '13', '14', '25', '26', '27', '28', '31', '32', '37', '38', '39', '49', '54', '59', '61', '64', '68', '70', '72', '75', '76', '79', '81', '83', '94', '97', '100', '101', '110', '111', '113', '116', '122', '123', '125', '129', '131', '134', '138', '140', '142', '144', '154', '158', '162', '168', '169', '171', '174', '176', '179', '183', '187', '193', '196', '207', '210', '211', '214', '216', '222', '226', '228', '229', '235', '244', '246', '249', '250', '255', '264', '270', '277', '279', '280', '282', '285', '286', '289', '292', '295', '300', '306', '309', '310', '312', '316', '319', '322', '323', '324', '326', '328', '330', '331', '332', '336', '348', '349', '350', '352', '354', '358', '360', '361', '366', '367', '383', '385', '388', '390', '391', '395', '400', '403', '407', '412', '416', '418', '420', '422', '423', '425', '430', '431', '433', '434', '435', '443', '444', '450', '461', '462', '473', '477', '483', '488', '492', '493', '498', '505', '507', '513', '514', '517', '518', '535', '537', '540', '542', '544', '549', '553', '558', '560', '563', '575', '582', '583', '587', '592', '593', '595', '599', '602', '603', '604', '606', '608', '609', '611', '612', '621', '634', '636', '637', '638', '639', '642', '644', '645', '646', '648', '654', '659', '660', '661', '664', '665', '670', '671', '674', '681', '684', '691', '697', '699', '700', '702', '705', '707', '709', '714', '716', '717', '723', '728', '732', '741', '742', '748', '751', '752', '753', '755', '757', '758', '760', '763', '764', '767', '770', '775', '777', '782', '788', '793', '795', '800', '801', '803', '804', '806', '807', '809', '812', '814', '817', '818', '819', '821', '822', '825', '828', '832', '835', '840', '841', '842', '844', '848', '849', '856', '864', '865', '873', '874', '887', '888', '891', '893', '900', '902', '907', '908', '909', '910', '912', '921', '931', '932', '935', '936', '937', '940', '942', '944', '947', '949', '952', '953', '955', '963', '964', '969', '973', '976', '980', '987', '992', '993', '996', '999', '1000', '1001', '1006', '1010', '1017', '1020', '1021', '1023', '1027', '1036', '1039', '1042', '1046', '1051', '1053', '1055', '1056', '1058', '1059', '1063', '1075', '1076', '1079', '1087', '1091', '1098', '1100', '1102', '1106', '1107', '1110', '1114', '1115', '1121', '1124', '1125', '1128', '1133', '1134', '1136', '1137', '1138', '1139', '1142', '1146', '1150', '1152', '1154', '1155', '1162', '1163', '1170', '1173', '1175', '1179', '1180', '1181', '1185', '1186', '1188', '1190', '1192', '1197', '1198', '1200', '1208', '1210', '1211', '1212', '1214', '1217', '1221', '1222', '1225', '1230', '1237', '1241', '1245', '1248', '1251', '1252', '1254', '1255', '1258', '1259', '1260', '1262', '1267', '1270', '1273', '1277', '1278', '1283', '1294', '1297', '1298', '1299', '1302', '1303', '1304', '1308', '1312', '1313', '1315', '1316', '1321', '1329', '1330', '1332', '1333', '1334', '1337', '1338', '1341', '1344', '1345', '1346', '1348', '1350', '1352', '1353', '1365', '1366', '1369', '1372', '1374', '1376', '1378', '1379', '1380', '1383', '1393', '1396', '1402', '1406', '1412', '1413', '1414', '1421', '1422', '1425', '1428', '1436', '1437', '1438', '1440', '1445', '1446', '1450', '1458', '1460', '1462', '1464', '1465', '1474', '1478', '1479', '1480', '1481', '1484', '1485', '1487', '1490', '1491', '1495', '1498', '1501', '1502', '1507', '1510', '1513', '1520', '1521', '1522', '1523', '1524', '1525', '1527', '1537', '1538', '1539', '1541', '1544', '1546', '1548', '1550', '1559', '1561', '1562', '1566', '1567', '1569', '1576', '1578', '1582', '1584', '1587', '1593', '1595', '1602', '1603', '1608', '1610', '1612', '1613', '1615', '1617', '1618', '1626', '1632', '1638', '1639', '1640', '1643', '1644', '1646', '1648', '1650', '1651', '1660', '1665', '1669', '1670', '1672', '1677', '1687', '1690', '1695', '1696', '1699', '1701', '1703', '1712', '1715', '1716', '1717', '1719', '1721', '1728', '1729', '1731', '1741', '1742', '1743 ...

# %%
pred_list
# Out:
# [3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3]

# %%
Counter(pred_list).most_common()[0][0]
# Out:
# 3

# %%
get_embedding('4', '101').shape
# Out:
# (258,)

# %%
np.argmax(model.predict(get_embedding('2063176', '1793668').reshape(1, -1))[0])
# Out:
# 1

# %%
knn_table['4']
# Out:
# [('1253543', 0.96214759349823),
#  ('4372428', 0.9609520435333252),
#  ('927204', 0.9608209133148193),
#  ('1741085', 0.9607545733451843),
#  ('4131175', 0.9602131247520447),
#  ('3147941', 0.9601165652275085),
#  ('1595803', 0.9600576162338257),
#  ('2562185', 0.9599236845970154),
#  ('1821701', 0.959648609161377),
#  ('25944', 0.9596140384674072),
#  ('5140108', 0.95953768491745),
